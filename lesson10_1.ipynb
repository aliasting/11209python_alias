# %%
- 猜中要告知猜了幾次
- 沒猜中要有提醒
import random
min = 1
max = 100
count = 0
target = random.randint(min, max)
print("===============猜數字遊戲=================:\n")
while(True):
   keyin = input(f"猜數字範圍{min}~{max}")
'''例如:
要猜的數值是:34

猜數字範圍1~100:50
提示:
再小一點
您已經猜了1次

猜數字範圍1~49:10
提示:
再大一點
您已經猜了2次
猜數字範圍11~49:34

您猜中了,答案是34
您總共猜了3次
'''

# %%
import random   #師
min = 1
max = 100
count = 0
target = random.randint(min, max)
print("===============猜數字遊戲=================:\n")
while(True):
    count += 1
    keyin = int(input(f"猜數字範圍{min}~{max}"))
    if (keyin >= 1 and keyin <= max):
        #if (1 <= keyin <= max):
        if(keyin == target):
            print(f"賓果!猜對了, 答案是:{target}")
            print(f"總共猜了{count}次")
            break
        elif (keyin > target):
            print("再小一點")
            max = keyin - 1
            
        elif (keyin < target):
            print("再大一點")
            min = keyin + 1
            
        print(f"您已經猜了{count}次")
    else:
        print("請輸入提示範圍內的數字")

print("遊戲結束!")

# %%
import random   #師
import pyinputplus as pyip

while True:
    min = 1
    max = 100
    count = 0
    target = random.randint(min, max)
    print(target)
    print("===============猜數字遊戲=================:\n")
    while(True):
        count += 1
        keyin = int(input(f"猜數字範圍{min}~{max}"))
        if (1 <= keyin <= max):
            if(keyin == target):
                print(f"賓果!猜對了, 答案是:{target}")
                print(f"總共猜了{count}次")
                break
            elif (keyin > target):
                print("再小一點")
                max = keyin - 1
                
            elif (keyin < target):
                print("再大一點")
                min = keyin + 1
                
            print(f"您已經猜了{count}次")
        else:
            print("請輸入提示範圍內的數字")
    answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
    if not (answer == 'y'):
        break
print("遊戲結束")

# %%
import random
import pyinputplus as pyip
while True:
    min = 1
    max = 100
    count = 0
    target = random.randint(min, max)
    print(target)
    print("===============猜數字遊戲=================:\n")
    while(True):
        count += 1
        keyin = int(input(f"猜數字範圍{min}~{max}"))
        if (1 <= keyin <= max):
            if(keyin == target):
                print(f"賓果!猜對了, 答案是:{target}")
                print(f"總共猜了{count}次")
                break
            elif (keyin > target):
                print("再小一點")
                max = keyin - 1
                
            elif (keyin < target):
            print("再大一點")
            min = keyin + 1
            
            print(f"您已經猜了{count}次")
        else:
            print("請輸入提示範圍內的數字")
    answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
    if not (answer == 'y'):
        break
print("遊戲結束!")

# %%
def guess_luckynumber():
      import random
      lucky_number=random.randint(1,10)  #電腦隨機選一個幸運號碼
 
      def guess_number():
             number=int(raw_input("Please enter an luncky number:"))  #使用者選一個號碼
             def guess(number):
                   if number==lucky_number:   #當兩號碼相同
                   print "Congratulations, you win nothing!"   #恭喜猜對了
                   elif number<lucky_number:  #比幸運數字小
                   print "Higher"
                   guess_number()                         #再猜一次
                   else:                                       #比幸運數字大
                   print "Lower"                           
                   guess_number()                         #再猜一次

            guess(number)
 
      guess_number()
guess_luckynumber()

# %%
def guess_luckynumber():
    import random
    lucky_number=random.randint(1,10)
    number=int(raw_input("Please enter an luncky number:"))
   
    while number!= lucky_number:  #當兩者不相等
        if number<lucky_number:
            print "Higher"
            number=int(raw_input("Please enter an luncky number:"))
        else:
            print "Lower"
            number=int(raw_input("Please enter an luncky number:"))
    print ‘done’   # 當while敘述不滿足時，跳出while迴圈要直行的東西
   
guess_luckynumber()
